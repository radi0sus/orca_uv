# %%
# !git clone https://github.com/radi0sus/orca_uv
# Out:
# Cloning into 'orca_uv'...
# remote: Enumerating objects: 114, done.
# remote: Counting objects: 100% (114/114), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 114 (delta 58), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (114/114), 1.28 MiB | 1.58 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
# below sample data obvtained from : https://www.orcasoftware.de/tutorials_orca/spec/UVVis.html#the-electronic-spectrum

sample_orca_output = '''
-----------------------------------------------------------------------------
         ABSORPTION SPECTRUM VIA TRANSITION ELECTRIC DIPOLE MOMENTS
-----------------------------------------------------------------------------
State   Energy    Wavelength  fosc         T2        TX        TY        TZ
        (cm-1)      (nm)                 (au**2)    (au)      (au)      (au)
-----------------------------------------------------------------------------
   1   19699.5    507.6   0.047917124   0.80078   0.87904  -0.16736   0.00724
   2   30354.1    329.4   0.012327447   0.13370   0.05769   0.36102  -0.00597
   3   31373.4    318.7   0.023725133   0.24896  -0.48626   0.08573  -0.07183
   4   32906.2    303.9   0.002354014   0.02355  -0.04012  -0.14813   0.00027
   5   34099.1    293.3   0.176508288   1.70411   1.27793  -0.24569  -0.10310
'''

with open("sample_orca.out", "w") as text_file:
    text_file.write(sample_orca_output)

# %%
# %matplotlib notebook
# %run /content/orca_uv/orca-uv.py --show /content/sample_orca.out
